# %% [markdown]
# #        Feature Extraction :

# %% [markdown]
# Feature Extraction is a process of selecting and extracting the most important feature from raw data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.Feature Scaling :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.Standardization(StandardScaler)
#
# ### >Standardization is the transformation of features by subtracting from mean and dividing by standard deviation. This is often called as Z-score.
# >It is also known as Z-Score Normalization

# %% [markdown]
# ## >Why we use it?
# ### standardization transforms data into a standard format, making it easier for computers to use and understand.
# #### It will scale the large data into small data with valuable information.
# >It is most used in Machine Learning.

# %% [markdown]
# ### *Z_score = (Xi-MeanofX)/Std*

# %% [markdown]
# ### Here, Where we apply SND then it will be Mean=0 and std=1

# %% [markdown]
# ## 2.Normalization( Min-Max Scaling)

# %% [markdown]
# ### >Normalization is used to transform features to be on a similar scale.
# #### >Normaliztion Which scale the range [0-1] or [-1,1]
# >It is most used in Deep Learning

# %% [markdown]
# ### X_Scaled = (X-X_min)/(X_max-X_min)

# %% [markdown]
# ## 3.Unit vector

# %% [markdown]
# ### >A unit vector is a vector of magnitude 1 and with a direction along a given vector. It represents the direction of the given vector.
# ### It is also a Feature Scaling Technique

# %% [markdown]
#  ### UNIT VECTOR FORMULA !

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Where |V| is the modulus of vector V

# %% [raw]
# #### Suppose our vectorofX=(3,4) FIND Magnitude of ||VectorX||
#
# ||X||=root(sqrt(3)+sqrt(4))
#      =root(9+16)
#      =root(25)
# ||X||=5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## unitvectorof(M)=(3/||vectorx||,4/||vectorx||)
#                         =(3/5,4/5)

# %% [raw]
# #### FIND Magnitude of ||VectorM||
#
# ||M||=root(sqrt(3/5)+sqrt(4/5))
#      =root(9/25+16/25)
#      =root(25/25)
#      =1

# %% [markdown]
# # 2.Feature Selection :-

# %%
## In Feature Selection we just pic the most important features

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MOST POPULAR TECHNIQUE:-
#
# #### 1.Filter Method
# #### 2.Wrapper Method
# #### 3.Embedded Method

# %% [markdown]
# ### 1.Filter Methods :

# %% [markdown]
# These methods are generally used while doing the pre-processing step. These methods select features from the dataset irrespective of the use of any machine learning algorithm.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#### 1.Chi-square test
#### 2.Correlation Coefficient 
#### 3.Variance Threshold

# %% [markdown]
# ### 2.Wrapper methods:

# %% [markdown]
# Wrapper methods, also referred to as greedy algorithms train the algorithm by using a subset of features in an iterative manner.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#### 1. Recursive Elimination
#### 2. Backward Elimination
#### 3. Forward Elimination

# %%
### 3.Embedded methods:

# %% [markdown]
# In embedded methods, the feature selection algorithm is blended as part of the learning algorithm, thus having its own built-in feature selection methods.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#### 1.Regularization
#### 2.Tree-based methods

# %% [markdown]
# # 3.PCA:-
# #### >Principal Component Analysis(PCA) can be used to identify the most important features in a dataset, which can be used to build predictive models.

# %% [markdown]
# >It is used to convert given data into 2D to 1D (Higher to Lower Dimentation) with less loss of information

# %% [markdown]
# ##### >How its works?
# #### It create an perfect plain that all data is converted to single plain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LDA:-

# %% [markdown]
# Linear Discriminant Analysis (LDA) is a supervised learning algorithm used for classification tasks in machine learning
