# %% [markdown]
# # Polynomial regression
#
# ![image.png](attachment:e763a4ae-8f28-4f5b-86b6-23f30c28470b.png)

# %% [markdown]
# ####  Where and Why Polynomial Regression is Used
# Polynomial regression is used when the relationship between the input variable(s) and the output is non-linear, but you still want to model it using a linear model in terms of parameters. It fits a curve (rather than a straight line) to the data.
