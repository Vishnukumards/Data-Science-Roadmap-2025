# %% [markdown]
# # ANN

# %% [markdown]
# A neural network is a very powerful machine learning mechanism which basically mimics how a human brain learns.

# %% [markdown]
# The brain receives the stimulus from the outside world, does the processing on the input, and then generates the output. As the task gets complicated, multiple neurons form a complex network, passing information among themselves.

# %% [markdown]
# ![image.png](attachment:11574711-78f8-42eb-8f96-a7de5ea7396f.png)

# %% [markdown]
# An Artificial Neural Network tries to mimic a similar behavior. The network you see below is a neural network made of interconnected neurons. Each neuron is characterized by its weight, bias and activation function.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Input is fed to Input layer  neurons perform linear tansformation on this input using the weights and biases.
#
# x = (weight * input) + bias
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The output from the activation function moves to the next hidden layer and the same process is repeated. This forward movement of information is known as the forward propagation.

# %% [markdown]
# ### What if the output generated is far away from the actual value?
#
# Using the output from the forward propagation, error is calculated. Based on this error value, the weights and biases of the neurons are updated. This process is known as back-propagation.

# %% [markdown]
# #### *A neural network without an activation function is essentially just a linear regression model.*
# So, It become less powerful and will not be able to learn Complex patterns from the Data.

# %% [markdown]
# # ACTIVATION FUNCTIONS :-
#  The main purpose of an activation function is to transform the summed weighted input from a node into an output value that is passed on to the next hidden layer or used as the final output.

# %% [markdown]
# # 1. Binary Step Function:- Binary step fuction is used on creating Binary Classification.
# #### Limitations == It is not helpful in multiple classes in the target Variable.
#
# f(x) = 1, x>=0
#      = 0, x<0
#
#     X vlaue is zero
#     Gradient of the function become zero.
#
#    ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Linear Function:- We can use Linear in case of Multiple classes
#     f(x)=ax
#
#   #### Limitations == Although gradient here does not become zero, but it is a constant which does not depend upon the input value x at all. This implies that the weights and biases will be updated during the backpropagation process but the updating factor would be the same.
#
#   ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Sigmoid :- It is one of the most widely used non-linear activation function. Sigmoid transforms the values between the range 0 and 1.
#
# ![image.png](attachment:image.png)
#
#
# It only takes value between 0 to 1 It can be interpreted as Probability in the  output layer most commonly used (Output Neuron).
#
# #### Drawbacks : It has drawbacks in hidden layer.
# Vanishing Gradient Problem.

# %% [markdown]
# # 4. Tanh Function :- It is similar to Sigmoid function it is stretched between -1 to 1 instead of  0. This make the advantages over sigmoid function when we use in the hidden layer.
#
# In Back Propagation or Gradient we need to use Derivative of cost function with respect to w and cost function.
# Cost function depends on Activation function so we should take the derivative of the activation functions as well.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# We can train our model using Tanh much faster as the derivative value is higher and works better in hidden layer where average is close to zero.
#
# #### Drawback == When we take the derivative of Activation Function and Cost function and while working on Gradient Descent we see for very high value of x or for very low value of x the derivative becomes very small This make Learning become very slow This is Called VANISHING GRADIENT PROBLEM(TO overcome this we use ReLU Fuction).

# %% [markdown]
# # 5. ReLU(Rectified Linear Unit):-
# Relu
#
# Rectified linear unit (ReLU) or rectifier activation function introduces the property of nonlinearity to a deep learning model and solves the vanishing gradients issue. It interprets the positive part of its argument. It is one of the most popular activation functions in deep learning.
#     It is a linear function where we rectify the input which is lessthan 0 so
#   ![image.png](attachment:image.png)
#
#   For x <= 0, 0
#   For x > 0, x
#
#   It is Picece Wise Linear as it can take the Advantage of both linear and No Linear property. Linearity of the fuction can help to work on the Vanishing Gradient Problem and also make training Faster. Because of the Non linearity benefits of using multiple Hidden layers in Neural Network

# %% [markdown]
# ## Variations of ReLU
#
# ### 1.LEAKY ReLU
# ### 2.ELU(Exponential Linear Unit)

# %% [markdown]
# LEAKY ReLU : - In leaky value instead of defining 0 we define it with help of a very small linear component of x.
#
#
#     f(x) = max(0.01*x,x)
#    ![image.png](attachment:image.png)

# %% [markdown]
# ELU ReLU:- The Exponential Linear Unit or ELU is a function that tends to converge faster and produce more accurate results. Unlike other activation functions, ELU has an extra alpha constant which should be a positive number. ELU is very similar to ReLU except for negative inputs. They are both in the identity function form for non-negative inputs.
#
#             f(x)=max(α*(e^x-1, x),x)

# %% [markdown]
# # 6. SoftMax Activation Function :-
#      It is popularly used for multiclass classification problems.
#      Instead of using sigmoid, we will use the Softmax activation function in the output layer in the above example. The Softmax activation function calculates the relative probabilities.
#
#          Here in Softmax it Calculate the Probability with exponential which makes small values smaller and big value bigger
#          Where as in Sigmoid it is not possible it RANGE the values between 0 to 1.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
