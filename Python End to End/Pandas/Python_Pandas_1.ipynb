# %%
# Pandas

# Pandas is a python library
# Pandas is used to analyze data
# Pandas is a Python library used for working with data set
# It's has function for analyzing,cleaning,exploring,and manipulating data.
# Pandas -'Python Data Analysis'

# %%
import pandas as pd

# %%
#version
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydata={'cars':["BMW","FORD"],"no_count":[1,2]}

# %%
myout=pd.DataFrame(mydata)

# %%
print(myout)
# Out:
#    cars  no_count
# 0   BMW         1
# 1  FORD         2

# %%
print(type(myout))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Pandas Series

# %%
a=[1,2,4]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    2
# 2    4
# dtype: int64

# %%
print(type(myvar))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(myvar[1])
# Out:
# 2

# %%
# labels

# %%
a=[1,2,4]
myvar=pd.Series(a,index=["a","b","c"])
print(myvar)
# Out:
# a    1
# b    2
# c    4
# dtype: int64

# %%
print(myvar["a"])
# Out:
# 1

# %%
# DATA FRAMES

# %%
data={"calories":[220,380,390],"duration":[50,40,45]}
df=pd.DataFrame(data)

# %%
df
# Out:
#    calories  duration
# 0       220        50
# 1       380        40
# 2       390        45

# %%
#Location

ab={"calories":[220,380,390],"duration":[50,40,45]}
df=pd.DataFrame(ab,index=["day1","day2","day3"])
df
# Out:
#       calories  duration
# day1       220        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day1"])
# Out:
# calories    220
# duration     50
# Name: day1, dtype: int64

# %%
df.loc["day4"]=[200,39]

# %%
df
# Out:
#       calories  duration
# day1       220        50
# day2       380        40
# day3       390        45
# day4       200        39

# %%
today = {"calories":[120,300,120],"duration":[60,80,15]}

# %%
today= pd.DataFrame(today)

# %%
#IndexLocation
print(today.iloc[0])
# Out:
# calories    120
# duration     60
# Name: 0, dtype: int64

# %%
today.iloc[3]=[234,30]

# %%
today
# Out:
#    calories  duration
# 0       120        60
# 1       300        80
# 2       120        15
# 3       234        30

# %%
# Loading CSV to pandas

# %%
data = pd.read_csv("filename.csv")

# %%
# loading Excel to pandas

# %%
data = pd.read_excel("filename.xlsx")

# %%
data = pd.read_json("filename.json")

# %%
#Loding JSON to pandas

# %%
# Importing Dataset

# %%
data = pd.read_csv("country_wise_latest.csv")

# %%
# Analyzing Data

# %%
# Viewing data
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
data.shape
# Out:
# (187, 15)

# %%
data.loc[187] = [None] * len(data.columns)
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_10052\3907886739.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data.loc[187] = [None] * len(data.columns)

# %%
# Data Cleaning

# %%
#  Check Empty cells(Nan values)
data.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
# 187            True       True    True       True    True       True
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            1
# Confirmed                 1
# Deaths                    1
# Recovered                 1
# Active                    1
# New cases                 1
# New deaths                1
# New recovered             1
# Deaths / 100 Cases        1
# Recovered / 100 Cases     1
# Deaths / 100 Recovered    1
# Confirmed last week       1
# 1 week change             1
# 1 week % increase         1
# WHO Region                1
# dtype: int64

# %%
data.isnull().any().sum()
# Out:
# 15

# %%
# To Drop nan values or we can Replace
df=data.dropna()

# %%
df.tail()
# Out:
#          Country/Region Confirmed Deaths Recovered Active New cases  \
# 182  West Bank and Gaza     10621     78      3752   6791       152
# 183      Western Sahara        10      1         8      1         0
# 184               Yemen      1691    483       833    375        10
# 185              Zambia      4552    140      2815   1597        71
# 186            Zimbabwe      2704     36       542   2126       192
#
#     New deaths New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182          2             0                0.73                  35.33
# 183          0             0               10.00                  80.00
# 184          4            36               28.56                  49.26
# 185          1           465                3.08                  61.84
# 186          2            24                1.33                  20.04
#
#      Deaths / 100 Recovered Confirmed last week 1 week change  \
# ...

# %%
# Replace using Mean,Median or Mode

# %%
# Why we use it because data is important to Train our model
# if it miss one important data then model will not give good accuracy value.So, we replace it with Mean,Median or Mode

# %%
data.replace([None , float('inf')],np.nan,inplace=True)
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_10052\2847165240.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace([None , float('inf')],np.nan,inplace=True)

# %%
data.tail()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 183  Western Sahara       10.0     1.0        8.0     1.0        0.0
# 184           Yemen     1691.0   483.0      833.0   375.0       10.0
# 185          Zambia     4552.0   140.0     2815.0  1597.0       71.0
# 186        Zimbabwe     2704.0    36.0      542.0  2126.0      192.0
# 187             NaN        NaN     NaN        NaN     NaN        NaN
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 183         0.0            0.0               10.00                  80.00
# 184         4.0           36.0               28.56                  49.26
# 185         1.0          465.0                3.08                  61.84
# 186         2.0           24.0                1.33                  20.04
# 187         NaN            NaN                 NaN                    NaN
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
print(data.isnull().sum())
# Out:
# Country/Region            1
# Confirmed                 1
# Deaths                    1
# Recovered                 1
# Active                    1
# New cases                 1
# New deaths                1
# New recovered             1
# Deaths / 100 Cases        1
# Recovered / 100 Cases     1
# Deaths / 100 Recovered    6
# Confirmed last week       1
# 1 week change             1
# 1 week % increase         1
# WHO Region                1
# dtype: int64

# %%
data["Confirmed"].mean()
# Out:
# 88130.935828877

# %%
data["Confirmed last week"].mean()
# Out:
# 78682.47593582887

# %%
df = data.fillna(data.mean(numeric_only = True))

# %%
df.tail()
# Out:
#          Country/Region Confirmed Deaths Recovered Active New cases  \
# 182  West Bank and Gaza     10621     78      3752   6791       152
# 183      Western Sahara        10      1         8      1         0
# 184               Yemen      1691    483       833    375        10
# 185              Zambia      4552    140      2815   1597        71
# 186            Zimbabwe      2704     36       542   2126       192
#
#     New deaths New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182          2             0                0.73                  35.33
# 183          0             0               10.00                  80.00
# 184          4            36               28.56                  49.26
# 185          1           465                3.08                  61.84
# 186          2            24                1.33                  20.04
#
#      Deaths / 100 Recovered Confirmed last week 1 week change  \
# ...

# %%
# Now all Nan columns are replaced with mean and only int is filled What about category data?

# %%
#specific column replace of mean, median and mode 
#Mean()
x = data["Confirmed"].mean()
data["Confirmed"].fillna(x,inplace =True)

# %%
#Median()
df["column_name"].fillna(x,inplace=True)

# %%
#Mode()
x = df["colum_name"].mode()

df["Daily new confirmed cases"].fillna(x,inplace=True)

# %%
df.dropna(inplace=True) 
# df.dropna(axis=1, inplace=True)

# # Drop Rows with Any Null Values
# We write inplace as True to make changes permanent
# axis is rows and columns : 1= Column and 0 = rows
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_10052\2433206843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#          Country/Region Confirmed Deaths Recovered Active New cases  \
# 0           Afghanistan     36263   1269     25198   9796       106
# 1               Albania      4880    144      2745   1991       117
# 2               Algeria     27973   1163     18837   7973       616
# 3               Andorra       907     52       803     52        10
# 4                Angola       950     41       242    667        18
# ..                  ...       ...    ...       ...    ...       ...
# 182  West Bank and Gaza     10621     78      3752   6791       152
# 183      Western Sahara        10      1         8      1         0
# 184               Yemen      1691    483       833    375        10
# 185              Zambia      4552    140      2815   1597        71
# 186            Zimbabwe      2704     36       542   2126       192
#
#     New deaths New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10            18                3.50                  69.49
# ...

# %%
# Grouping
df.groupby('Country/Region')['Confirmed'].mean()
# Out:
# Country/Region
# Afghanistan           36263.0
# Albania                4880.0
# Algeria               27973.0
# Andorra                 907.0
# Angola                  950.0
#                        ...
# West Bank and Gaza    10621.0
# Western Sahara           10.0
# Yemen                  1691.0
# Zambia                 4552.0
# Zimbabwe               2704.0
# Name: Confirmed, Length: 187, dtype: float64

# %%
# we slice the wanted table with specific rows and column as we leant in list

# %%
data.iloc[:8,:3]
# Out:
#         Country/Region  Confirmed  Deaths
# 0          Afghanistan    36263.0  1269.0
# 1              Albania     4880.0   144.0
# 2              Algeria    27973.0  1163.0
# 3              Andorra      907.0    52.0
# 4               Angola      950.0    41.0
# 5  Antigua and Barbuda       86.0     3.0
# 6            Argentina   167416.0  3059.0
# 7              Armenia    37390.0   711.0

# %%
df[["Country/Region","Confirmed","Deaths","Active"]]  #specific column
# Out:
#          Country/Region Confirmed Deaths Active
# 0           Afghanistan     36263   1269   9796
# 1               Albania      4880    144   1991
# 2               Algeria     27973   1163   7973
# 3               Andorra       907     52     52
# 4                Angola       950     41    667
# ..                  ...       ...    ...    ...
# 182  West Bank and Gaza     10621     78   6791
# 183      Western Sahara        10      1      1
# 184               Yemen      1691    483    375
# 185              Zambia      4552    140   1597
# 186            Zimbabwe      2704     36   2126
#
# [187 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df[df["Confirmed"]<1500]
# Out:
#                        Country/Region Confirmed Deaths Recovered Active  \
# 3                             Andorra       907     52       803     52
# 4                              Angola       950     41       242    667
# 5                 Antigua and Barbuda        86      3        65     18
# 11                            Bahamas       382     11        91    280
# 14                           Barbados       110      7        94      9
# 17                             Belize        48      2        26     20
# 19                             Bhutan        99      0        86     13
# 22                           Botswana       739      2        63    674
# 24                             Brunei       141      3       138      0
# 26                       Burkina Faso      1100     53       926    121
# 27                              Burma       350      6       292     52
# 28                            Burundi       378      1       301     76
# ...

# %%
df[df["Deaths"]>10000]
# Out:
#      Country/Region Confirmed  Deaths Recovered   Active New cases New deaths  \
# 23           Brazil   2442375   87618   1846641   508116     23284        614
# 61           France    220352   30212     81212   108928      2551         17
# 79            India   1480073   33408    951166   495499     44457        637
# 81             Iran    293606   15912    255144    22550      2434        212
# 85            Italy    246286   35112    198593    12581       168          5
# 111          Mexico    395489   44022    303810    47657      4973        342
# 132            Peru    389717   18418    272547    98752     13756        575
# 138          Russia    816680   13334    602249   201097      5607         85
# 157           Spain    272421   28432    150376    93613         0          0
# 173              US   4290259  148011   1325804  2816444     56336       1076
# 177  United Kingdom    301708   45844      1437   254427       688          7
#
# ...

# %%
# can convert data to list
list(data["Confirmed"])
# Out:
# [36263.0,
#  4880.0,
#  27973.0,
#  907.0,
#  950.0,
#  86.0,
#  167416.0,
#  37390.0,
#  15303.0,
#  20558.0,
#  30446.0,
#  382.0,
#  39482.0,
#  226225.0,
#  110.0,
#  67251.0,
#  66428.0,
#  48.0,
#  1770.0,
#  99.0,
#  71181.0,
#  10498.0,
#  739.0,
#  2442375.0,
#  141.0,
#  10621.0,
#  1100.0,
#  350.0,
#  378.0,
#  2328.0,
#  226.0,
#  17110.0,
#  116458.0,
#  4599.0,
#  922.0,
#  347923.0,
#  86783.0,
#  257101.0,
#  354.0,
#  3200.0,
#  8844.0,
#  15841.0,
#  15655.0,
#  4881.0,
#  2532.0,
#  1060.0,
#  15516.0,
#  13761.0,
#  5059.0,
#  18.0,
#  64156.0,
#  81161.0,
#  92482.0,
#  15035.0,
#  3071.0,
#  265.0,
#  2034.0,
#  2316.0,
#  14547.0,
#  27.0,
#  7398.0,
#  220352.0,
#  7189.0,
#  326.0,
#  1137.0,
#  207112.0,
#  33624.0,
#  4227.0,
#  14.0,
#  23.0,
#  45309.0,
#  7055.0,
#  1954.0,
#  389.0,
#  7340.0,
#  12.0,
#  39741.0,
#  4448.0,
#  1854.0,
#  1480073.0,
#  100303.0,
#  293606.0,
#  112585.0,
#  25892.0,
#  63985.0,
#  246286.0,
#  853.0,
#  31142.0,
# ...

# %%
df.sort_values("Confirmed")
# Out:
#             Country/Region Confirmed  Deaths Recovered   Active New cases  \
# 183         Western Sahara        10       1         8        1         0
# 75                Holy See        12       0        12        0         0
# 68               Greenland        14       0        13        1         1
# 140  Saint Kitts and Nevis        17       0        15        2         0
# 49                Dominica        18       0        18        0         0
# ..                     ...       ...     ...       ...      ...       ...
# 154           South Africa    452529    7067    274925   170537      7096
# 138                 Russia    816680   13334    602249   201097      5607
# 79                   India   1480073   33408    951166   495499     44457
# 23                  Brazil   2442375   87618   1846641   508116     23284
# 173                     US   4290259  148011   1325804  2816444     56336
#
#     New deaths New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data["Confirmed"].value_counts()
# Out:
# Confirmed
# 24.0        2
# 86.0        2
# 10621.0     2
# 109597.0    1
# 9132.0      1
#            ..
# 1137.0      1
# 207112.0    1
# 33624.0     1
# 4227.0      1
# 2704.0      1
# Name: count, Length: 184, dtype: int64

# %%
data[data["Confirmed"]>2000]  # list all data has more than 2000 conformed
# Out:
#          Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0           Afghanistan    36263.0  1269.0    25198.0   9796.0      106.0
# 1               Albania     4880.0   144.0     2745.0   1991.0      117.0
# 2               Algeria    27973.0  1163.0    18837.0   7973.0      616.0
# 6             Argentina   167416.0  3059.0    72575.0  91782.0     4890.0
# 7               Armenia    37390.0   711.0    26665.0  10014.0       73.0
# ..                  ...        ...     ...        ...      ...        ...
# 179          Uzbekistan    21209.0   121.0    11674.0   9414.0      678.0
# 180           Venezuela    15988.0   146.0     9959.0   5883.0      525.0
# 182  West Bank and Gaza    10621.0    78.0     3752.0   6791.0      152.0
# 185              Zambia     4552.0   140.0     2815.0   1597.0       71.0
# 186            Zimbabwe     2704.0    36.0      542.0   2126.0      192.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
d1 = pd.DataFrame({"Cl1":[2,3,4,78],"cl2":[14,22,88,11]})

# %%
d2 = pd.DataFrame({"cl1":[1,2,3,5],"cl2":[22,33,455,66]})

# %%
dd = pd.merge(d1,d2)

# %%
pd.Series(list(df["Country/Region"])[2:7],index=["a","b","c","d","e"])
# Out:
# a                Algeria
# b                Andorra
# c                 Angola
# d    Antigua and Barbuda
# e              Argentina
# dtype: object

# %%
#adding New column 

df["daily_check"]= 0.5*len(df)
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_10052\2610873565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["daily_check"]= 0.5*len(df)

# %%
df
# Out:
#          Country/Region Confirmed Deaths Recovered Active New cases  \
# 0           Afghanistan     36263   1269     25198   9796       106
# 1               Albania      4880    144      2745   1991       117
# 2               Algeria     27973   1163     18837   7973       616
# 3               Andorra       907     52       803     52        10
# 4                Angola       950     41       242    667        18
# ..                  ...       ...    ...       ...    ...       ...
# 182  West Bank and Gaza     10621     78      3752   6791       152
# 183      Western Sahara        10      1         8      1         0
# 184               Yemen      1691    483       833    375        10
# 185              Zambia      4552    140      2815   1597        71
# 186            Zimbabwe      2704     36       542   2126       192
#
#     New deaths New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10            18                3.50                  69.49
# ...

# %%
df.drop("daily_check",axis = 1)
# Out:
#          Country/Region Confirmed Deaths Recovered Active New cases  \
# 0           Afghanistan     36263   1269     25198   9796       106
# 1               Albania      4880    144      2745   1991       117
# 2               Algeria     27973   1163     18837   7973       616
# 3               Andorra       907     52       803     52        10
# 4                Angola       950     41       242    667        18
# ..                  ...       ...    ...       ...    ...       ...
# 182  West Bank and Gaza     10621     78      3752   6791       152
# 183      Western Sahara        10      1         8      1         0
# 184               Yemen      1691    483       833    375        10
# 185              Zambia      4552    140      2815   1597        71
# 186            Zimbabwe      2704     36       542   2126       192
#
#     New deaths New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10            18                3.50                  69.49
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
data["WHO Region"].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia', nan], dtype=object)

# %%
# Read Url data 
url_data = pd.read_html("https://finance.yahoo.com/markets/")

# %%
import pandas as pd
import requests

url = "https://finance.yahoo.com/markets/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

# Parse HTML tables from the content
tables = pd.read_html(response.text)

# Example: Print the first table
print(tables[0].head())
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_10052\3439373789.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
#                     Symbol  Unnamed: 1                       Price Change %
# 0                      VIX         NaN        25.29 +0.14 (+0.56%)   +0.56%
# 1             Russell 2000         NaN     1,965.55 +7.93 (+0.41%)   +0.41%
# 2  S&P/TSX Composite index         NaN   24,798.59 +88.08 (+0.36%)   +0.36%
# 3          US Dollar Index         NaN        99.31 +0.30 (+0.30%)   +0.30%
# 4                   Dow 30         NaN  40,227.59 +114.09 (+0.28%)   +0.28%

# %%
tables[0]
# Out:
#                     Symbol  Unnamed: 1                        Price Change %
# 0                      VIX         NaN         25.29 +0.14 (+0.56%)   +0.56%
# 1             Russell 2000         NaN      1,965.55 +7.93 (+0.41%)   +0.41%
# 2  S&P/TSX Composite index         NaN    24,798.59 +88.08 (+0.36%)   +0.36%
# 3          US Dollar Index         NaN         99.31 +0.30 (+0.30%)   +0.30%
# 4                   Dow 30         NaN   40,227.59 +114.09 (+0.28%)   +0.28%
# 5                 IBOVESPA         NaN  135,015.89 +276.61 (+0.21%)   +0.21%
# 6                  S&P 500         NaN      5,528.75 +3.54 (+0.06%)   +0.06%
# 7                   Nasdaq         NaN    17,366.13 -16.81 (-0.10%)   -0.10%
# 8                      NaN         NaN                          NaN      NaN

# %%
tables[0].dtypes
# Out:
# Symbol         object
# Unnamed: 1    float64
# Price          object
# Change %       object
# dtype: object

# %%
### StringIO
### Pandas read_csv
##📘 What Is StringIO?
## StringIO lets you treat a string like a file — read from it, write to it, or pass it to functions (like pd.read_csv) that expect file-like objects.
from io import StringIO

# %%
from io import StringIO
import pandas as pd

csv_data = """Name,Score
Alice,90
Bob,85
Charlie,92"""

df = pd.read_csv(StringIO(csv_data))
print(df)
# Out:
#       Name  Score
# 0    Alice     90
# 1      Bob     85
# 2  Charlie     92

# %%
from io import StringIO

buffer = StringIO()
buffer.write("Hello\n")
buffer.write("World\n")

# Move cursor to the start to read it
buffer.seek(0)
print(buffer.read())
# Out:
# Hello
# World

# %%
output = StringIO()
df.to_csv(output, index=False)

# Get the string value
csv_string = output.getvalue()
print(csv_string)
# Out:
# Name,Score
# Alice,90
# Bob,85
# Charlie,92

# %%
def read_file_like(file_obj):
    return file_obj.read().upper()

fake_file = StringIO("hello world")
print(read_file_like(fake_file))
# Out:
# HELLO WORLD

# %%
data = '{"Student_name":"Vishnu Kumar D S","email":"vishnukumardsvishnu@gmail.com","job_profile":"Data Scientist"}'

# %%
import pandas as pd
import json

df = pd.DataFrame([json.loads(data)])

print(df)
# Out:
#        Student_name                          email     job_profile
# 0  Vishnu Kumar D S  vishnukumardsvishnu@gmail.com  Data Scientist

# %%
pd.read_json(data,orient = "index")
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_15252\48777710.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data,orient = "index")
#                                           0
# Student_name               Vishnu Kumar D S
# email         vishnukumardsvishnu@gmail.com
# job_profile                  Data Scientist

# %%
pd.read_json(data,orient = "columns")
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_15252\2114848324.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json(data,orient = "columns")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_json(data,orient = "columns")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
# ...

# %%
#Suppose our dataset has date is wrong
df["Date"]=pd.to_datetime(df["Date"])
print(df.to_string())

# %%
# Replacing Values
# Suppose 'Daily New Tests' has 107 instaid of 7.So, how to replace it

df.loc[107,"Daily New Tests"]=7

# %%
# Removing Rows

# Delete rows if it has higher values
#Example:
for x in df.index:
    if df.loc[x,"Daily New Tests"]>20:
        df.drop(x,inplace=True)

# %%
# For Duplicate row 

print(df.duplicate())

#To Drop

print(df.drop_duplicate())

# %%
# PANDAS -CORRELATION

# it is used to find the relationship between data
# corr() method
# Number varies (-1 to 1)

# %%
df.corr()
# Out:
#                            Daily new confirmed cases  Total confirmed cases  \
# Daily new confirmed cases                   1.000000               0.466735
# Total confirmed cases                       0.466735               1.000000
# Daily new deaths                            0.623610               0.373513
# Total deaths                                0.430891               0.989046
# Daily new recovered                         0.158416               0.458575
# Total recovered                             0.335708               0.897136
# Daily New Tests                             0.560005               0.812907
# Total Tests                                 0.443392               0.941350
# Active Cases                                0.510066               0.929646
#
#                            Daily new deaths  Total deaths  \
# Daily new confirmed cases          0.623610      0.430891
# Total confirmed cases              0.373513      0.989046
# ...

# %%
# Perfect Correlation

# 1 is Perfect Correlation
# o.9972 is bad Correlation
